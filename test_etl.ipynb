# %% [markdown]
# to do:
#     objectif métier
#     1) une classe( mère) abstraite record (load) → (class enfant) to_csv qui récup le df → pour l'enregistrer en CSV
#     2) une classe ( mère) abstraite obj_client →(classe enfant)  ville, station , record

# %%
from extractors.meteo_toulouse_extractor import MeteoToulouseExtractor
from extractors.meteo_toulouse_extractor import MeteoToulouseExtractor
from validators.dataframe_validator import DataFrameValidator
import pandas as pd 
from extractors.stations_config import STATIONS

# %%
def load_data_api(station: str) -> pd.DataFrame:
    """Extrait et valide les données d'une station donnée."""
    extractor = MeteoToulouseExtractor(station)
    data_json = extractor.extract()
    df = extractor.to_dataframe(data_json)

    # Validation simple
    try:
        DataFrameValidator.validate(df)
        print(f"✅ Données valides pour {station} ({len(df)} lignes)")
    except Exception as e:
        print(f"⚠️  Erreur dans la validation de {station} :", e)

    return df


def merge_all_stations() -> pd.DataFrame:
    """Concatène les DataFrames de toutes les stations disponibles."""
    list_df = []

    for station in STATIONS.keys():
        try:
            print(f"🔍 Extraction en cours pour : {station}")
            df_station = load_data_api(station)

            # Ajout d'une colonne pour identifier la station dans la fusion
            df_station["station_name"] = station

            list_df.append(df_station)

        except Exception as e:
            print(f"❌ Erreur pour {station} → pas grave, on continue ({e})")

    # Fusionner toutes les stations sans erreur
    if list_df:
        df_final = pd.concat(list_df, ignore_index=True)
        print(f"\n🎯 Fusion terminée : {len(df_final)} lignes au total.")
        return df_final
    else:
        print("🚫 Aucune donnée n’a pu être extraite.")
        return pd.DataFrame()

# %%
df = merge_all_stations()
# Out:
# 🔍 Extraction en cours pour : montaudran
# ✅ Données valides pour montaudran (96 lignes)
# 🔍 Extraction en cours pour : colomiers_zi_enjacca
# ✅ Données valides pour colomiers_zi_enjacca (95 lignes)
# 🔍 Extraction en cours pour : parc_maourine
# ✅ Données valides pour parc_maourine (88 lignes)
# 🔍 Extraction en cours pour : marengo
# ❌ Erreur pour marengo → pas grave, on continue (Erreur API 404: {
#   "error_code": "NotFoundResource",
#   "message": "The requested dataset 2-station-meteo-toulouse-marengo does not exist."
# })
# 🔍 Extraction en cours pour : pech_david
# ✅ Données valides pour pech_david (78 lignes)
# 🔍 Extraction en cours pour : compans_cafarelli
# ✅ Données valides pour compans_cafarelli (96 lignes)
# 🔍 Extraction en cours pour : fondeyre
# ✅ Données valides pour fondeyre (14 lignes)
# 🔍 Extraction en cours pour : paul_sabatier
# ✅ Données valides pour paul_sabatier (92 lignes)
# 🔍 Extraction en cours pour : mondouzil
# ⚠️  Erreur dans la validation de mondouzil : Le DataFrame est vide
# 🔍 Extraction en cours pour : basso_cambo
# ❌ Erreur pour basso_cambo → pas grave, on continue (Erreur API 404: {
#   "error_code": "NotFoundResource",
#   "message": "The requested dataset 8-station-meteo-toulouse-basso-cambo does not exist."
# })
# 🔍 Extraction en cours pour : soupetard
# ✅ Données valides pour soupetard (14 lignes)
# 🔍 Extraction en cours pour : mons_epuration
# ✅ Données valides pour mons_epuration (2 lignes)
# 🔍 Extraction en cours pour : saint_jory_beldou
# ✅ Données valides pour saint_jory_beldou (10 lignes)
# 🔍 Extraction en cours pour : jardin_des_plantes
# ❌ Erreur pour jardin_des_plantes → pas grave, on continue (Erreur API 400: {
#   "error_code": "ODSQLError",
#   "message": "ODSQL query is malformed: Unknown field: heure_de_paris. Clause(s) containing the error(s): select."
# })
# 🔍 Extraction en cours pour : la_machine_af
# ⚠️  Erreur dans la validation de la_machine_af : Le DataFrame est vide
# 🔍 Extraction en cours pour : life_marechal_juin
# ❌ Erreur pour life_marechal_juin → pas grave, on continue (Erreur API 400: {
#   "error_code": "ODSQLError",
#   "message": "ODSQL query is malformed: Unknown field: heure_de_paris. Clause(s) containing the error(s): select."
# })
# 🔍 Extraction en cours pour : metropole
# ❌ Erreur pour metropole → pas grave, on continue (Erreur API 404: {
#   "error_code": "NotFoundResource",
#   "message": "The requested dataset 1-station-meteo-toulouse-metropole does not exist."
# })
# 🔍 Extraction en cours pour : mondonville_ecole
# ⚠️  Erreur dans la validation de mondonville_ecole : Le DataFrame est vide
# 🔍 Extraction en cours pour : teso
# ⚠️  Erreur dans la validation de teso : Le DataFrame est vide
# 🔍 Extraction en cours pour : zi_thibaud
# ⚠️  Erreur dans la validation de zi_thibaud : Le DataFrame est vide
# 🔍 Extraction en cours pour : busca
# ❌ Erreur pour busca → pas grave, on continue (Erreur API 404: {
#   "error_code": "NotFoundResource",
#   "message": "The requested dataset 3-station-meteo-toulouse-busca does not exist."
# })
# 🔍 Extraction en cours pour : pibrac_bouconne
# ⚠️  Erreur dans la validation de pibrac_bouconne : Le DataFrame est vide
# 🔍 Extraction en cours pour : life_hall1
# ❌ Erreur pour life_hall1 → pas grave, on continue (Erreur API 404: {
#   "error_code": "NotFoundResource",
#   "message": "The requested dataset 5-station-meteo-toulouse-life-hall-1 does not exist."
# })
# 🔍 Extraction en cours pour : nakache
# ❌ Erreur pour nakache → pas grave, on continue (Erreur API 404: {
#   "error_code": "NotFoundResource",
#   "message": "The requested dataset 5-station-meteo-toulouse-nakache does not exist."
# })
# 🔍 Extraction en cours pour : casselardit
# ⚠️  Erreur dans la validation de casselardit : Le DataFrame est vide
# 🔍 Extraction en cours pour : st_exupery
# ⚠️  Erreur dans la validation de st_exupery : Le DataFrame est vide
#
# 🎯 Fusion terminée : 585 lignes au total.

# %%
df.to_csv("data_meteo_toulouse_station/data_csv.csv")
