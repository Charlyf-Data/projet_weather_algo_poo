# %% [markdown]
# TP :
# 	Le client à besoins /
# 		SOCI2T2  / Météo
# 		Application suivre l’app meteto toullousaine
# 		 Data météo
# 		Donné ouverte
# 		Récupérer la data
# 		Crée un model conceptualise mes data en poo
# 		Tous en respectant solid
# 		Collecte traite, nettoie-t-on les doc avant et après traitement, je l’affiche
# 		Station de meteo par métro
# 		La prévision
#             leins :
#
#
# class récupération de data
# @une méthode statique
# 	request
#
#
# class nettoyage
# 	.d
#
# class afficher
#
# class créateur ville
# 	self
# 	nom
#
# class station
# 	self
# 	nom = []
#
#
# class créateur de stations
#
# class température
#
# class humidité
#
# class préssion

# %% [markdown]
# # Importation test

# %%
import requests as re

# %%
url = "https://data.toulouse-metropole.fr/api/explore/v2.1/catalog/datasets/42-station-meteo-toulouse-parc-compans-cafarelli/records"
params = {
    "select": "id, humidite, pression, temperature_en_degre_c",
    "limit": 10
}

# %%
response = re.get(url, params=params)

# %%
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Erreur lors de la requête :", response.text)
# Out:
# {'total_count': 163365, 'results': [{'id': 42, 'humidite': 79, 'pression': 99700, 'temperature_en_degre_c': 13.2}, {'id': 42, 'humidite': 66, 'pression': 99900, 'temperature_en_degre_c': 17.5}, {'id': 42, 'humidite': 71, 'pression': 99900, 'temperature_en_degre_c': 16.6}, {'id': 42, 'humidite': 70, 'pression': 99900, 'temperature_en_degre_c': 16.9}, {'id': 42, 'humidite': 77, 'pression': 99700, 'temperature_en_degre_c': 14.3}, {'id': 42, 'humidite': 72, 'pression': 99900, 'temperature_en_degre_c': 16.5}, {'id': 42, 'humidite': 72, 'pression': 99900, 'temperature_en_degre_c': 16.2}, {'id': 42, 'humidite': 77, 'pression': 99800, 'temperature_en_degre_c': 14.8}, {'id': 42, 'humidite': 62, 'pression': 100000, 'temperature_en_degre_c': 18.3}, {'id': 42, 'humidite': 72, 'pression': 99800, 'temperature_en_degre_c': 18.0}]}

# %%
data = response.json()

# %%
data
# Out:
# {'total_count': 163365,
#  'results': [{'id': 42,
#    'humidite': 79,
#    'pression': 99700,
#    'temperature_en_degre_c': 13.2},
#   {'id': 42,
#    'humidite': 66,
#    'pression': 99900,
#    'temperature_en_degre_c': 17.5},
#   {'id': 42,
#    'humidite': 71,
#    'pression': 99900,
#    'temperature_en_degre_c': 16.6},
#   {'id': 42,
#    'humidite': 70,
#    'pression': 99900,
#    'temperature_en_degre_c': 16.9},
#   {'id': 42,
#    'humidite': 77,
#    'pression': 99700,
#    'temperature_en_degre_c': 14.3},
#   {'id': 42,
#    'humidite': 72,
#    'pression': 99900,
#    'temperature_en_degre_c': 16.5},
#   {'id': 42,
#    'humidite': 72,
#    'pression': 99900,
#    'temperature_en_degre_c': 16.2},
#   {'id': 42,
#    'humidite': 77,
#    'pression': 99800,
#    'temperature_en_degre_c': 14.8},
#   {'id': 42,
#    'humidite': 62,
#    'pression': 100000,
#    'temperature_en_degre_c': 18.3},
#   {'id': 42,
#    'humidite': 72,
#    'pression': 99800,
#    'temperature_en_degre_c': 18.0}]}

# %%
class origine :
    def personne( self, atribut, parle ):
        self.atribut: str  = atribut
        self.parle : str = parle
